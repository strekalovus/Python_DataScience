# %% [markdown]
# ##Задание 1

# %% [markdown]
# Импортируем библиотеки pandas и numpy.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Загружаем "Boston House Prices dataset" из встроенных наборов данных библиотеки sklearn.

# %%
from sklearn.datasets import load_boston

# %% [markdown]
# Именуем ключевые показатели

# %%
boston = load_boston()
data = boston.data
target = boston.target # величина, которую требуется предсказать
feature_names = boston.feature_names # названия признаков

# %% [markdown]
# Создаём датафреймы X и y из этих данных.

# %%
X = pd.DataFrame(data, columns=feature_names)
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %%
y = pd.DataFrame(target, columns=['price'])
y.head()
# Out:
#    price
# 0   24.0
# 1   21.6
# 2   34.7
# 3   33.4
# 4   36.2

# %% [markdown]
# Разбиваем эти датафреймы на тренировочные (X_train, y_train) и тестовые (X_test, y_test) с помощью функции train_test_split так, чтобы размер тестовой выборки составлял 30% от всех данных, при этом аргумент random_state должен быть равен 42.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Создаём модель линейной регрессии под названием lr с помощью класса LinearRegression из модуля sklearn.linear_model.

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %% [markdown]
# Обучаем модель на тренировочных данных (используем все признаки) и делаем предсказание на тестовых.

# %%
lr.fit(X_train, y_train) # обучаем модель
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X_test) # делаем предсказание на тестовых

# %%
# смотрим результаты в сравнении
check_test = pd.DataFrame({'y_test': y_test['price'],
                           'y_pred': y_pred.flatten()},
                          columns=['y_test', 'y_pred'])
check_test.head()
# Out:
#      y_test     y_pred
# 173    23.6  28.648960
# 274    32.4  36.495014
# 491    13.6  15.411193
# 72     22.8  25.403213
# 452    16.1  18.855280

# %% [markdown]
# Вычисляем R2 полученных предказаний с помощью r2_score из модуля sklearn.metrics.

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7112260057484974

# %% [markdown]
# ##Задание 2

# %% [markdown]
# Создаём модель под названием model с помощью RandomForestRegressor из модуля sklearn.ensemble.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# обучаем модель
model = RandomForestRegressor(max_depth=12, n_estimators=1000, random_state=42)
model.fit(X_train, y_train.values[:, 0])
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=12, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=1000, n_jobs=None, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
# делаем предсказание на тестовых
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8749965273218174

# %% [markdown]
# Применение модели Random Forest даёт лучший результат, чем применение модели Linear Regression
